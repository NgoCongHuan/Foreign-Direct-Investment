# %%
# Kết nối với google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 16.0 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (3.0.10)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.25.2)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (2.0.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.11.4)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (0.14.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (2.0.7)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (67.7.2)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (24.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->pmdarima) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.0.4

# %%
import pandas as pd

# %%
# Load tập dữ liệu
df = pd.read_csv('/content/drive/MyDrive/Foreign-Direct-Investment/data/fdi_industry_vi.csv',index_col='TT')

# %%
# In ra 5 dòng đầu tiên
df.head(5)
# Out:
#                                                Ngành  Số dự án cấp mới   \
# TT
# 1                      Công nghiệp chế biến, chế tạo                955
# 2      Sản xuất, phân phối điện, khí, nước, điều hòa                  9
# 3                  Hoạt động kinh doanh bất động sản                 34
# 4                                           Xây dựng                112
# 5   Bán buôn và bán lẻ; sửa chữa ô tô, mô tô, xe máy                306
#
#     Vốn đăng ký cấp mới (triệu USD)   Số lượt dự án điều chỉnh   \
# TT
# 1                             8927.8                        517
# 2                             2795.3                          8
# 3                             2146.4                         12
# 4                              573.6                         26
# 5                              375.2                         89
#
#     Vốn đăng ký điều chỉnh\n(triệu USD)   Số lượt góp vốn mua cổ phần   \
# TT
# 1                                 6305.4                           NaN
# 2                                   14.0                           NaN
# 3                                  248.3                           NaN
# 4                                  162.9                           NaN
# 5                                  166.8                           NaN
#
#     Giá trị góp vốn, mua cổ phần \n(triệu USD)    Năm
# TT
# 1                                           NaN  2015
# 2                                           NaN  2015
# 3                                           NaN  2015
# 4                                           NaN  2015
# 5                                           NaN  2015

# %%
# Thống kê các cột có trong DataFrame
print("Column before modification:")
for x, column in enumerate(df.columns):
    print("Column {}: {}".format(x, column))

print("------------------------------")
print("Modification processing...")
# Loại bỏ khoảng trắng ở đầu và cuối mỗi tên cột
df.columns = df.columns.str.strip()

# Đổi ký tự " \n" thành " "
df.columns = df.columns.str.replace(" \n"," ")

# Đổi ký tự "\n" thành ""
df.columns = df.columns.str.replace("\n"," ")
print("------------------------------")

# Kiểm tra lại các cột có trong DataFrame
print("Column after modification:")
for x, column in enumerate(df.columns):
    print("Column {}: {}".format(x, column))
# Out:
# Column before modification:
# Column 0: Ngành
# Column 1:  Số dự án cấp mới
# Column 2:  Vốn đăng ký cấp mới (triệu USD)
# Column 3:  Số lượt dự án điều chỉnh
# Column 4:  Vốn đăng ký điều chỉnh
# (triệu USD)
# Column 5:  Số lượt góp vốn mua cổ phần
# Column 6:  Giá trị góp vốn, mua cổ phần
# (triệu USD)
# Column 7: Năm
# ------------------------------
# Modification processing...
# ------------------------------
# Column after modification:
# Column 0: Ngành
# Column 1: Số dự án cấp mới
# Column 2: Vốn đăng ký cấp mới (triệu USD)
# Column 3: Số lượt dự án điều chỉnh
# Column 4: Vốn đăng ký điều chỉnh (triệu USD)
# Column 5: Số lượt góp vốn mua cổ phần
# Column 6: Giá trị góp vốn, mua cổ phần (triệu USD)
# Column 7: Năm

# %%
# Khởi tạo mảng chứa các cột cần loại bỏ khoảng trắng trong mỗi giá trị
column_to_strip = df.drop('Năm', axis=1).columns

# Khởi tạo vòng lặp duyệt qua các giá trị trong cột và loại bỏ khoảng trắng dư thừa
for column in column_to_strip:
  df[column] = df[column].str.strip()

# %%
# Thống kê số lượng các giá trị thiếu ở mỗi cột
print(df.isnull().sum())
print("-> The total number of initial null values is: {}".format(df.isnull().sum().sum()))

print("------------------------------")
print("Fillna processing...")
# Thay thế số giá trị null thành 0
# Thay thế các chuỗi có dạng " -" và "- " thành ""
df = df.replace('-',0)
df = df.fillna(0)
print("------------------------------")

# Kiểm tra lại số giá trị null
print(df.isnull().sum())
print("-> The total number of null values after substitution is: {}".format(df.isnull().sum().sum()))
# Out:
# Ngành                                        0
# Số dự án cấp mới                             1
# Vốn đăng ký cấp mới (triệu USD)              0
# Số lượt dự án điều chỉnh                     6
# Vốn đăng ký điều chỉnh (triệu USD)           6
# Số lượt góp vốn mua cổ phần                 26
# Giá trị góp vốn, mua cổ phần (triệu USD)    26
# Năm                                          0
# dtype: int64
# -> The total number of initial null values is: 65
# ------------------------------
# Fillna processing...
# ------------------------------
# Ngành                                       0
# Số dự án cấp mới                            0
# Vốn đăng ký cấp mới (triệu USD)             0
# Số lượt dự án điều chỉnh                    0
# Vốn đăng ký điều chỉnh (triệu USD)          0
# Số lượt góp vốn mua cổ phần                 0
# Giá trị góp vốn, mua cổ phần (triệu USD)    0
# Năm                                         0
# dtype: int64
# -> The total number of null values after substitution is: 0

# %%
# Loại bỏ đuôi .00 và dấu ,
df['Số lượt góp vốn mua cổ phần'] = df['Số lượt góp vốn mua cổ phần'].replace('.00','', regex=True)
df['Số lượt góp vốn mua cổ phần'] = df['Số lượt góp vốn mua cổ phần'].replace(',','', regex=True)

# Khởi tạo mảng chứa các cột cần chuyển đổi kiểu int
column_to_int = ['Số dự án cấp mới', 'Số lượt dự án điều chỉnh', 'Số lượt góp vốn mua cổ phần']

# Khởi tạo vòng lặp để chuyển đổi các cột sang kiểu int
for column in column_to_int:
  df[column] = df[column].astype(int)

# %%
# Khởi tạo mảng chứa các cột cần chuyển đổi kiểu float
column_to_float = ['Vốn đăng ký cấp mới (triệu USD)', 'Vốn đăng ký điều chỉnh (triệu USD)', 'Giá trị góp vốn, mua cổ phần (triệu USD)']

# Khởi tạo vòng lặp để chuyển đổi các cột sang kiểu float
for column in column_to_float:

  # Xóa các kí tự đặc biệt
  df[column] = df[column].replace(',','', regex=True)
  df[column] = df[column].replace('\(','',regex=True)
  df[column] = df[column].replace('\)','',regex=True)

  # Chuyển đổi sang kiểu float
  df[column] = df[column].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, 1 to 150
# Data columns (total 8 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Ngành                                     150 non-null    object
#  1   Số dự án cấp mới                          150 non-null    int64
#  2   Vốn đăng ký cấp mới (triệu USD)           150 non-null    float64
#  3   Số lượt dự án điều chỉnh                  150 non-null    int64
#  4   Vốn đăng ký điều chỉnh (triệu USD)        150 non-null    float64
#  5   Số lượt góp vốn mua cổ phần               150 non-null    int64
#  6   Giá trị góp vốn, mua cổ phần (triệu USD)  150 non-null    float64
#  7   Năm                                       150 non-null    int64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 10.5+ KB

# %%
df.head()
# Out:
#                                                Ngành  Số dự án cấp mới  \
# TT
# 1                      Công nghiệp chế biến, chế tạo               955
# 2      Sản xuất, phân phối điện, khí, nước, điều hòa                 9
# 3                  Hoạt động kinh doanh bất động sản                34
# 4                                           Xây dựng               112
# 5   Bán buôn và bán lẻ; sửa chữa ô tô, mô tô, xe máy               306
#
#     Vốn đăng ký cấp mới (triệu USD)  Số lượt dự án điều chỉnh  \
# TT
# 1                            8927.8                       517
# 2                            2795.3                         8
# 3                            2146.4                        12
# 4                             573.6                        26
# 5                             375.2                        89
#
#     Vốn đăng ký điều chỉnh (triệu USD)  Số lượt góp vốn mua cổ phần  \
# TT
# 1                               6305.4                            0
# 2                                 14.0                            0
# 3                                248.3                            0
# 4                                162.9                            0
# 5                                166.8                            0
#
#     Giá trị góp vốn, mua cổ phần (triệu USD)   Năm
# TT
# 1                                        0.0  2015
# 2                                        0.0  2015
# 3                                        0.0  2015
# 4                                        0.0  2015
# 5                                        0.0  2015

# %%
import pmdarima as pm

############################## Hàm Thêm dữ liệu ##############################
def fill_data(df):

  # Thống kê các năm và đối tượng
  objects = df.iloc[:,0].unique()
  years = df.iloc[:,-1].unique()

  # Duyệt qua từng đối tượng
  for obj in objects:

    # DataFrame tạm thời chứa thông tin nguồn vốn của đối tượng qua các năm
    df_temp = df[df.iloc[:,0] == obj]

    # Thống kê các năm mà đối tượng này không có dữ liệu
    years_of_obj = [y for y in years if y not in df_temp.iloc[:,-1].values]

    # Thêm dữ liệu vào các năm mà đối tượng không tồn tại
    if years_of_obj:

      for year in years_of_obj:

        data = {}

        data[df.columns[0]] = obj
        data[df.columns[-1]] = year

        for col in df.columns[1:-1]:
          data[col] = 0

        df_new = pd.DataFrame([data])

        df = pd.concat([df,df_new], ignore_index=True)

  return df

############################## Hàm xoá dữ liệu đã thêm ##############################
def remove_fill_data(df):

  df = df[df[df.columns[1:-1]].sum(axis=1) != 0]

  return df

############################## Hàm dự đoán từng đặc trưng ##############################
def predict_fdi(df):

  df = df.sort_values(by='Năm')

  data = df.iloc[:,1].values

  # Khởi tạo mô hình
  model = pm.auto_arima(data, seasonal=False, trace=True)

  n_periods = 3
  forecasts = model.predict(n_periods=n_periods)

  results = forecasts

  return results

############################## Hàm dự đoán tất cả đặc trưng ##############################
def main(df):

  df = fill_data(df)

  for obj in df.iloc[:,0].unique():

    df_temp = df[df.iloc[:,0] == obj]

    data_predict = {}

    for col in df_temp.columns[1:-1]:

      results = predict_fdi(df_temp[[df_temp.columns[0], col, df_temp.columns[-1]]])

      data_predict[col] = results

    data_predict[df_temp.columns[-1]] = [y for y in range(2023,2026)]

    data_predict[df_temp.columns[0]] = [obj for i in range(2023,2026)]

    df_predict = pd.DataFrame(data_predict)

    df = pd.concat([df, df_predict], ignore_index=True)

  df = remove_fill_data(df)

  df = df.reset_index(drop=True)

  return df

df = main(df)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=118.872, Time=0.11 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=134.005, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=117.028, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=118.965, Time=0.06 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.10 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=115.056, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=115.243, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=115.454, Time=0.07 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=115.920, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=114.031, Time=0.06 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=115.812, Time=0.09 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=117.965, Time=0.09 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[0] intercept
# Total fit time: 0.817 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=153.845, Time=0.19 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=169.871, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=154.679, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.17 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.46 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=inf, Time=0.10 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=155.882, Time=0.05 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.19 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.16 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0]
# Total fit time: 1.461 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.25 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=129.943, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=110.502, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=inf, Time=0.11 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=111.692, Time=0.12 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=112.963, Time=0.32 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=104.161, Time=0.11 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=102.282, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=104.090, Time=0.10 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.27 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.412 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=148.235, Time=0.29 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=164.551, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=148.176, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=160.705, Time=0.08 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=148.757, Time=0.12 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=149.666, Time=0.29 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=141.992, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=139.929, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=141.927, Time=0.12 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.30 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.368 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=132.293, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=138.232, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=130.571, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=134.668, Time=0.10 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=132.070, Time=0.16 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.25 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=131.199, Time=0.14 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0]
# Total fit time: 0.803 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=153.196, Time=0.12 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=153.426, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=152.047, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC
Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=24.190, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=24.453, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=20.904, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=22.739, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=22.565, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.17 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.398 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.11 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=69.514, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=71.513, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=71.513, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=69.198, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=70.059, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.11 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.357 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.10 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=52.335, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=50.274, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=inf, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=52.273, Time=0.02 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=49.812, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=48.156, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.12 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.522 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=58.947, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=56.999, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=58.550, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=58.791, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=54.143, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=54.305, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.289 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=40.593, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=48.311, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=39.574, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=inf, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=40.367, Time=0.02 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.10 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=40.155, Time=0.02 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0]
# Total fit time: 0.241 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=93.749, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=95.673, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=95.676, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=94.232, Time=0.01 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0]
# Total fit time: 0.146 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=39.376, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=40.412, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=38.627, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=40.316, Time=0.02 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.13 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=38.349, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=36.971, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=37.301, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=39.156, Time=0.06 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.409 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=120.565, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=122.563, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=122.564, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=121.210, Time=0.01 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0]
# Total fit time: 0.152 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=63.771, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=63.289, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=62.670, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=63.576, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=64.099, Time=0.03 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=65.769, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=60.635, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=58.650, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=60.627, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.322 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=71.339, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=73.303, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=73.308, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=71.608, Time=0.01 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0]
# Total fit time: 0.140 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=58.583, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=56.446, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=56.390, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=56.598, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=57.391, Time=0.02 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.14 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=49.704, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=49.984, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=47.775, Time=0.05 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=48.063, Time=0.21 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0] intercept
# Total fit time: 0.689 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=107.884, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=109.884, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=inf, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=108.554, Time=0.01 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0]
# Total fit time: 0.138 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=32.930, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=36.955, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=31.528, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=35.605, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=32.589, Time=0.02 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=34.389, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=29.395, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=27.533, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=29.394, Time=0.02 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=31.391, Time=0.12 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.325 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.13 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=93.513, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=95.415, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=95.458, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=92.358, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=93.443, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=95.440, Time=0.12 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.440 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=70.825, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=77.276, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=68.831, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=inf, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=70.821, Time=0.02 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.10 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=68.072, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=66.150, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=68.048, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.06 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.373 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=121.916, Time=0.20 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=118.767, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=119.943, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=119.922, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=118.481, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=120.444, Time=0.11 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=120.403, Time=0.17 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.17 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.800 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=20.041, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=20.943, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=18.825, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=20.013, Time=0.11 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=20.621, Time=0.09 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=22.020, Time=0.41 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=17.064, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=15.096, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=16.970, Time=0.08 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=18.594, Time=0.18 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.133 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.29 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=24.539, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=26.344, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=26.347, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=24.070, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=25.880, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.25 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.985 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=12.067, Time=0.15 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=8.067, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=10.067, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=10.067, Time=0.11 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=8.999, Time=0.04 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0]
# Total fit time: 0.384 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=33.843, Time=0.19 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=29.843, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=31.843, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=31.843, Time=0.20 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=30.775, Time=0.01 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0]
# Total fit time: 0.469 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=12.067, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=8.067, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=10.067, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=10.067, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=8.999, Time=0.03 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0]
# Total fit time: 0.204 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=2.502, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-1.498, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=0.502, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=0.502, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-0.566, Time=0.05 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0]
# Total fit time: 0.206 seconds

# %%
df.to_csv('/content/drive/MyDrive/Foreign-Direct-Investment/data/fdi_industry_vi_clean.csv', encoding='utf-8-sig', index=False)

# %%
df_clean = pd.read_csv('/content/drive/MyDrive/Foreign-Direct-Investment/data/fdi_industry_vi_clean.csv')

df_clean.head()
# Out:
#                                               Ngành  Số dự án cấp mới  \
# 0                     Công nghiệp chế biến, chế tạo             955.0
# 1     Sản xuất, phân phối điện, khí, nước, điều hòa               9.0
# 2                 Hoạt động kinh doanh bất động sản              34.0
# 3                                          Xây dựng             112.0
# 4  Bán buôn và bán lẻ; sửa chữa ô tô, mô tô, xe máy             306.0
#
#    Vốn đăng ký cấp mới (triệu USD)  Số lượt dự án điều chỉnh  \
# 0                           8927.8                     517.0
# 1                           2795.3                       8.0
# 2                           2146.4                      12.0
# 3                            573.6                      26.0
# 4                            375.2                      89.0
#
#    Vốn đăng ký điều chỉnh (triệu USD)  Số lượt góp vốn mua cổ phần  \
# 0                              6305.4                          0.0
# 1                                14.0                          0.0
# 2                               248.3                          0.0
# 3                               162.9                          0.0
# 4                               166.8                          0.0
#
#    Giá trị góp vốn, mua cổ phần (triệu USD)   Năm
# 0                                       0.0  2015
# 1                                       0.0  2015
# 2                                       0.0  2015
# 3                                       0.0  2015
# 4                                       0.0  2015
